# %%
for i in range(1, 10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# os
import os

# %%
# 系统相关内容
print(os.name)
print(os.environ)
print(os.sep) #几种标识符
print(os.pathsep)
print(os.linesep)
os.linesep
# Out:
# posix
# ...

# %%
# 文件和目录操作
# os.mkdir("folder's_name") #创建文件夹
# os.rmdir("folder's_name") #删除文件夹
# mkdirs rmdirs创建和删除多级目录
print(os.getcwd())
# Out:
# /Users/lk/XJTU_Research/Code_Playground
